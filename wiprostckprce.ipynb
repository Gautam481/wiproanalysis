# %%
import pandas as pd
import numpy as np3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Quote-Equity-WIPRO-EQ-05-06-2022-to-05-06-2023.csv")

# %%
dataset.head()
# Out:
#          Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0  05-Jun-2023      EQ  408.90  409.75  403.70        404.95  404.55  404.20
# 1  02-Jun-2023      EQ  408.70  409.80  404.00        407.15  405.35  404.95
# 2  01-Jun-2023      EQ  405.00  408.00  404.05        403.65  407.40  407.15
# 3  31-May-2023      EQ  401.75  404.80  400.50        402.50  403.90  403.65
# 4  30-May-2023      EQ  400.00  403.85  399.45        399.80  403.00  402.50
#
#     vwap   52W H   52W L     VOLUME             VALUE  No of trades
# 0  405.51  476.15   352.0  3,626,430  1,470,554,210.75        65,499
# 1  406.53  488.00   352.0  3,160,377  1,284,773,695.60        67,783
# 2  406.86  488.00   352.0  3,532,742  1,437,320,552.70        59,327
# 3  403.43  488.00   352.0  5,891,791  2,376,934,523.20        61,934
# 4  402.23  488.00   352.0  3,689,486  1,484,010,896.85        76,385

# %%
dataset.shape
# Out:
# (248, 14)

# %%
dataset.columns
# Out:
# Index(['Date ', 'series ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ',
#        'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
dataset[ 'series '].

# %%
dataset.isnull().sum()
# Out:
# Date             0
# series           0
# OPEN             0
# HIGH             0
# LOW              0
# PREV. CLOSE      0
# ltp              0
# close            0
# vwap             0
# 52W H            0
# 52W L            0
# VOLUME           0
# VALUE            0
# No of trades     0
# dtype: int64

# %%
dataset.drop([ 'series '],axis=1,inplace=True)

# %%
dataset
# Out:
#            Date    OPEN    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0    05-Jun-2023  408.90  409.75  403.70        404.95  404.55  404.20
# 1    02-Jun-2023  408.70  409.80  404.00        407.15  405.35  404.95
# 2    01-Jun-2023  405.00  408.00  404.05        403.65  407.40  407.15
# 3    31-May-2023  401.75  404.80  400.50        402.50  403.90  403.65
# 4    30-May-2023  400.00  403.85  399.45        399.80  403.00  402.50
# ..           ...     ...     ...     ...           ...     ...     ...
# 243  10-Jun-2022  467.20  467.20  456.30        475.05  461.20  460.95
# 244  09-Jun-2022  467.05  476.15  464.25        470.40  475.65  475.05
# 245  08-Jun-2022  471.05  472.00  464.30        467.65  470.00  470.40
# 246  07-Jun-2022  470.00  470.75  465.15        473.20  467.20  467.65
# 247  06-Jun-2022  472.00  475.50  464.20        475.50  473.80  473.20
#
#       vwap   52W H   52W L     VOLUME             VALUE  No of trades
# ...

# %%
dataset.describe()
# Out:
#             OPEN        HIGH         LOW   PREV. CLOSE         ltp   \
# count  248.000000  248.000000  248.000000    248.000000  248.000000
# mean   400.755242  403.573790  396.618347    400.245363  400.130444
# std     20.649823   21.006287   20.009127     21.103639   20.526024
# min    358.000000  360.750000  352.000000    356.200000  356.450000
# 25%    387.800000  390.237500  384.575000    387.612500  387.637500
# 50%    399.250000  402.600000  395.450000    398.500000  398.975000
# 75%    410.500000  414.012500  406.175000    410.550000  410.112500
# max    472.000000  476.150000  465.150000    475.500000  475.650000
#
#            close        vwap       52W H       52W L
# count  248.000000  248.000000  248.000000  248.000000
# mean   399.957863  399.989718  674.249597  377.610081
# std     20.552754   20.480715   84.009148   18.911507
# min    356.200000  357.320000  476.150000  352.000000
# 25%    387.612500  387.390000  616.000000  372.400000
# ...

# %%
dataset[ 'OPEN '].plot(figsize=(18,8))

# %%
dataset[ 'close '].plot(figsize=(18,8))

# %%
dataset[ 'HIGH '].plot(figsize=(18,8))

# %%
indep=dataset[[ 'OPEN ', 'HIGH ', 'LOW ']]
dep=dataset[[ 'close ']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=1)

# %%
y_train.shape
# Out:
# (173, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
weight=reg.coef_
print(weight)
# Out:
# [[-11.94657994  14.51077427  16.84103375]]

# %%
bais=reg.intercept_
print(bais)
# Out:
# [399.72283237]

# %%
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
print (r_score)
# Out:
# 0.9918966858615421
